# %% [markdown]
# # ••• 🌎 ・•◦•・ 🌎 ・•◦•・ 🌎 ・•◦•・ 🌎 ・•◦•・ 🌎 ・•◦•・ 🌎 ・•◦•・ 🌎 ・•◦•・ 🌎 •••
# # Around the World in Eighty Days

# %%
"""
DocString:
    
    A) Introduction:
    This is the "Around the World in Eighty Days" game, based on the adventure 
    novel written by Jules Verne and published for the first time in France in
    1892. The present game consists of 4 stages, each of which represents a 
    milestone for the proper completion of the world journey adventure. In 
    almost every stage the player might either lose or win the game. No book 
    knowledge is required to be able to properly complete the game;
    
    The various stages of the game are listed below
        Stop 1: Mumbai, the earth of India
        Stop 2: Hong Kong, the mystery of the lost clock
        Stop 3: New York, the big apple 
        Stop 4: Fourth stop
   
    B) Known Bugs and/or Errors:
    None.   
    
"""

# Importing packages
import random 




# Constructing my room_1, renamed introduction().

def introduction():
    # Printing game introduction.
    print("""London 🇬🇧, 1872. Reworn Club.\n""")
    input("< Please, press any key to continue the adventure >\n\n") # Prompting player for input to continue the game.
    
    print("""It was a rainy 🌧 morning in October when, inside one of the most  
prestigious bars of the city, an ambitious bet has been initiated by a 
small group of the young enriched bourgeois 🎩.\n""")
    input("< Please, press any key to continue the adventure >\n") # Prompting player for input to continue the game.
    
    print(f"""
{'・•◦•・' * 12}
        
                    Around the world in just eighty days! 🌎
        
{'・•◦•・' * 12} """)
    
    print("""\nWas it really possible? 🤔 Or was it just madness fueled by an insane 
youthful naivety? Now, it's your turn to find it out!!\n""")
    input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
    
    print("""Wait 🙌🏻... I forgot to introduce myself. What rudeness! 🤦🏻‍♂️""")
    print("""I am Passepartout, your faithful devoted servant ☺️. I will follow you  
step by step in this exciting adventure. But before to start, what's your name?\n""") # Prompting player for input to continue the game.
    
    # Creating a player-defined variable, called player_name to let the player input his/her name.
    player_name = input(prompt = """Please, write your name in the box ☺️: """)
    
    # Converting player_name using .capitalize() 
    player_name = player_name.capitalize()
    
    # Dynamically applying player_name.
    print(f"""\n\nGlad to met you {player_name}!""")
    print("""And, just one more question... What is your favorite hobby?\n""")
    
    # Creating a player-defined variable, called player_hobby, to let the player input his/her hobby.
    player_hobby = input(prompt = """< Please, write your favourite hobby in the box ☺️: """)
    
    # Converting player_hobby using .capitalize() 
    player_hobby = player_hobby.capitalize()
    
    # Dynamically applying player_hobby.
    print(f"""\n\n{player_hobby}? Really? {player_hobby} is also my favorite hobby!
Well, I'm sure that we will get along well 🤩.""")
    print("""Good, let's go! Time is running out! ⏱\n""")
    input("< Please, press any key to continue >") # Prompting player for input to continue the game.
    print(f"""\n\n\n{'▼△'*39}\n\n\n""") # Creating a nice desing to be printed at the end of the present stage.
    input("< Please, press any key to continue >\n") # Prompting player for input to continue the game.
    pre_departure() # Linking introduction() stage to pre_departure() stage. 



    
# Constructing my room_2, renamed pre_departure().

def pre_departure():
    # Prompting player for input, three choices are given, each of them leads to a different game path.
    transportation = input(prompt = """It is time to say goodbye to our beloved London and leave for our adventure! 
Which kind of transport do you want to use to start our journey?
                                    1. Train 🚂
                                    2. Sheep 🐑
                                    3. Ship 🚢                             
Please, input the number or the name of your preference: """)

    # Converting transportation using .casefold() to remove case distiction present in the string.
    transportation = transportation.casefold()
    
    # Creating a conditional function, based to the player the transportation prompt. 
    if transportation == '1' or transportation == 'train' in transportation:
        print(f"""\n\nWise choice! 👏🏻 You have chosen the fastest way to travel, we will save
precious time! Next stop, Mumbai 🇮🇳.\n""")
        input("< Please, press any key to continue >") # Prompting player for input to continue the game.
        print(f"""\n\n\n{'▼△'*39}\n\n\n""") # Creating a nice desing to be printed at the end of the present stage.
        input("< Please, press any key to continue >\n") # Prompting player for input to continue the game.
        stop_mumbai() # Linking the present player choice ('1' or 'train') to the stop_mumbai stage().
    
    elif transportation == '2' or transportation == 'sheep' in transportation:
        print(f"""\n\nOh no! 😢 You have chosen the slowest way to travel! We will never make it  
to complete our adventure in time riding a sheep .\n""")
        input("< Please, press any key to continue >\n") # Prompting player for input to continue the game.
        fail() # Linking the present player choice ('2' or 'sheep') to the fail() stage.
        
    elif transportation == '3' or transportation == 'ship' in transportation:
        print("""\n\nNot bad! Certainly not the fastest transport, but at least we could enjoy
the view and relax a bit before arriving in the enigmatic Mumbai🇮🇳.\n""")
        input("< Please, press any key to continue >") # Prompting player for input to continue the game.
        print(f"""\n\n\n{'▼△'*39}\n\n\n""") # Creating a nice desing to be printed at the end of the present stage.
        input("< Please, press any key to continue >\n") # Prompting player for input to continue the game.
        stop_mumbai() # Linking pre_depature() stage to stop_mumbai() stage.
    
    else: # Creating an else statement to let the player input his/her choice again if something went wrong his/her input.
        print("\n\nOh no!😢 Something went wrong. Please, try again.\n")
        input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
        pre_departure() # Linking to pre_depature() stage.

        

        
# Constructing my room_3, renamed stop_mumbai()

def stop_mumbai():
    # Printing stop_mumbai() stage introduction.
    print("""After long days of travel, we can finally see the splendid city of Mumbai, 
the heart of India. So beautiful to looks like a mirage ✨✨.\n""")
    input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
    print("""We are about to cross the gates of the city when an elderly 👳🏾‍♂️ man interrupts 
our walk. 
                                      "ALT!✋🏾" 
    "If you wish to continue your journey, you must pay the entrance fee!💰" he screams.\n\n""")
    input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
    
    # Prompting player for input, two choices are given, each of them leads to a different game path.
    entrance_fee = input(prompt = """Do you want to pay it or not❓
                                1. Pay ❗️
                                2. Let's change the path! ❌
Please, input the number or the name of your choice (e.g. 1 or pay): """)
     
    # Converting entrance_fee using .casefold() to remove case distiction present in the string.
    entrance_fee = entrance_fee.casefold()
    
    # Creating a conditional function, connected to the player entrance_fee prompt. 
    if entrance_fee == '1' or entrance_fee == 'pay' in entrance_fee:
        print("""\n\n                   Well, now you are good to go!"👍🏾 he says.\n\n""")
        input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
        
        
        # Prompting player for input, two choices are given, each of them leads to a different game path.
        eating_break = input (prompt = """We are right on time on our schedule ⏱, what about eating something 🍽?
                                1. Yes
                                2. No
Please, input your preference (e.g. 1 or yes): """)
                    
        # Converting eating_break using .casefold() to remove case distiction present in the string.
        eating_break = eating_break.casefold()
        
        # Creating a nested conditional function, connected to the player etrance_fee input '1' or 'pay'.
        if eating_break == '1' or eating_break == 'yes' in eating_break:
             
            
            # Prompting player for input, two choices are given, each of them leads to a different game path.
            meal_preference = input (prompt = """\n\nGreat, I was just starving! What would you like to eat?
                                1. Samosa 🥠
                                2. Pizza 🍕
Please, input the number or the name of your meal preference: """)
                        
            # Converting meal_preference using .casefold() to remove case distiction present in the string.
            meal_preference = meal_preference.casefold()
                        
            # Creating a second nested conditional function, connected to the player eating_break input '1' or 'yes'.
            if meal_preference == '1' or meal_preference == 'samosa' in meal_preference:
                print(f"""\n\nWonderful, I've never eaten samosa! Let's try some indian food and have a well deserved break. 
Next stop, Hong Kong 🇭🇰.\n""")
                input("< Please, press any key to continue >") # Prompting player for input to continue the game.
                print(f"""\n\n\n{'▼△'*39}\n\n\n""") # Creating a nice desing to be printed at the end of the present stage.
                input("< Please, press any key to continue >\n") # Prompting player for input to continue the game.
                stop_hongkong() # Linking stop_mumbai() stage to stop_hongkong stage().
                            
            elif meal_preference == '2' or meal_preference == 'pizza' in meal_preference:
                print(f"""\n\nOh no! This pizza doesn't look good, and you are turning green 🤢. It is spoiled! 
We need to bring you immediatly to the nearest hospital!{'🚑'*9}{'💨'*3}\n""")
                input("< Please, press any key to continue >") # Prompting player for input to continue the game.
                fail() # Linking to stop_mumbai() stage to fail() stage.
                            
            else: # Creating an else statement to let the player input his/her choice again if something went wrong his/her input.
                print("\n\nOh no!😢 Something went wrong. Please, try again.\n\n")
                input("< Please, press any key to continue >\n") # Prompting player for input to continue the game.
                stop_mumbai() # Linking to stop_mumbai() stage to stop_mumbai() stage to try again.
                 
                    
        # Continuation of the first nested conditional function, connected to the player entrance_fee input '2' or 'no'.
        elif eating_break == '2'or eating_break == 'no' in eating_break:
            print("""\n\nRight! We cannot afford any distraction. Once the bet will be won, we will have a lifetime to rest!
Let's continue our journey: next stop Hong Kong 🇭🇰.""")
            print(f"""\n\n\n{'▼△'*39}\n\n\n""") # Creating a nice desing to be printed at the end of the present stage.
            input("< Please, press any key to continue >\n") # Prompting player for input to continue the game.
            stop_hongkong() # Linking stop_mumbai() stage to stop_hongkong stage().
                    
        else: # Creating an else statement to let the player input his/her choice again if something went wrong his/her input.
            print("\n\nOh no!😢 Something went wrong. Please, try again.\n\n") 
            input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
            stop_mumbai() # Linking to stop_mumbai() stage to stop_mumbai() stage to try again.
            
            
    # Continuation of the conditional function, connected to entrance_fee prompt.
    elif entrance_fee == '2' or entrance_fee == 'change' or entrance_fee == 'path' in entrance_fee:
        print("""\n\nDue to this deviation, we will run out of schedule ⏱. But we can stil do it! 
Let's go to Chennai. Once we will arrive, we will take a ship to Hong Kong 🇭🇰 as soon as possible!""")
        print(f"""\n\n\n{'▼△'*39}\n\n\n""") # Creating a nice desing to be printed at the end of the present stage.
        input("< Please, press any key to continue >\n") # Prompting player for input to continue the game.
        stop_hongkong() # Linking stop_mumbai() stage to stop_hongkong stage()
              
    else: # Creating an else statement to let the player input his/her choice again if something went wrong his/her input.
        print("\n\nOh no!😢 Something went wrong. Please, try again.\n\n")
        input("< Please, press any key to continue >\n") # Prompting player for input to continue the game.
        stop_mumbai() # Linking to stop_mumbai() stage to stop_mumbai() stage to try again.
                
            
            
                            
def stop_hongkong():
    # Printing stop_hongkong() stage introduction.
    print("""We are almost halfway through our journey. Only a few minutes away from 
Hong Kong 🇭🇰! \n""") 
    input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
    print("""Look! There is a road sign blocking the passage 🛑✋""") 
    input("\n< Please, press any key to continue >\n") # Prompting player for input to continue the game.
    print(f"""
{'・•◦•・' * 12}\n
                            
                                  歡迎來到香港！

                          由於正在進行的工程，道路暫時封閉。

                            向左轉，朝努爾蘇丹方向行駛。

                             向右轉，朝舊金山方向行駛。\n

{'・•◦•・' * 12}\n""")
    
    # Prompting player for input, two choices are given, each of them leads to a different game path.      
    path = input( prompt = """What the hell does it say? 😰\n 
Only two streets are accessible. Which path do you want to take?
                            1. Right ↗️!
                            2. Letf ↖️!
Please, input the number or the direction of where you desire to go : """)
    
    # Converting path using .casefold() to remove case distiction present in the string.
    path = path.casefold()
                        
    # Creating a conditional function, connected to the player path prompt.
    if path == '1' or path == 'right' in path:
        print("""\n\nI believe we are heading in the right direction! Well done my dear friend! 🤩\n""")
        input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
          
    elif path == '2' or path == 'left' in path:
        print("""\n\nOh no! We are heading in the wrong direction! We are heading back to London by way of 
Nur-Sultan 🇰🇿""")
        print(f"""Unfortunately, your journey around the world ends here.\n""")
        input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
        fail()  # Linking to stop_hongkong() stage to fail() stage.
    
    else: # Creating an else statement to let the player input his/her choice again if something went wrong his/her input.
        print("\n\nOh no!😢 Something went wrong. Please, try again.\n")
        input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
        stop_hongkong()  # Linking to stop_hongkong() stage to stop_hongkong() stage to try again.
           
    # Continuing the story after the conditional function, connected to path prompt.
    print("""Hong Kong is truly a fascinating city, but I prefer our gloomy London 🌧. 
Too much chaos here...""")
    print("""What the hell! That running guy almost knocked you out of the push he gave you 🤬!""")
    print("""Check your bag, in case he has stolen something from your bag 🧳.\n\n""")
    input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
    
    # Prompting player for input, two choices are given, each of them leads to a different game path.   
    bag_check = input(prompt = """Do you want to check your bag? 🧳 
                                1. Yes
                                2. No
Please, input your preference (e.g. 1 or Yes): """)
    
    # Converting path_choice using .casefold() to remove case distiction present in the string.
    bag_check = bag_check.casefold()
    
    # Creating a conditional function, connected to bag_check prompt.
    if bag_check == '1' or bag_check == 'yes' in bag_check:
        print("""\n\nGreat, let's check!🔍\n""")
        input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
        
          
        
##############################################################################     
########################### The "What's missing Game" ########################
##############################################################################
       
       # Declaring objects 
        whats_missing = ''
        
        # Defining the maximum number of chances.
        chances = 3

        # Creating a conditional function, connected to the what_missing prompt.
        while chances > 0:
            # Prompting player to guess which item of the bag is missing.   
            whats_missing = input(prompt = """Guess what item is missing...🤔
                                        1. Passport 📜
                                        2. Glasses 👓
                                        3. Chocolate 🍫
                                        4. Apple 🍎
                                        5. Pencil ✏️                    
Please, input the number of your guess: """)


            # Converting path using .casefold() to remove case distiction present in the string.
            whats_missing = whats_missing.lower()

            if whats_missing == '4' or whats_missing == 'apple' in whats_missing:
                print("""\n\nYou guessed right it! Now we can continue our journey. Next stop: 
New York 🗽!""")
                print(f"""\n\n\n{'▼△'*39}\n\n\n""") # Creating a nice desing to be printed at the end of the present stage.
                input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
                stop_newyork() # Linking to stop_hongkong() stage to stop_newyork() stage. 
                break 

            elif whats_missing == '1' or whats_missing == 'glasses' in whats_missing:
                chances -= 1
                print("Good try, but something is else is missing 😢!\n\n")
                input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.


            elif whats_missing == '2' or whats_missing == 'glasses' in whats_missing:
                chances -= 1
                print("Good try, but something is else is missing 😢!\n\n")
                input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.


            elif whats_missing == '3' or whats_missing == 'chocolate' in whats_missing:
                chances -= 1
                print("Good try, but something is else is missing 😢!\n\n")
                input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.


            elif whats_missing == '5' or whats_missing == 'pencil' in whats_missing:
                chances -= 1
                print("Good try, but something is else is missing 😢!\n\n")
                input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.


            else: # Creating an else statement to let the player input his/her choice again if something went wrong his/her input.
                chances -= 1
                print("Oh no!😢 Something went wrong. Please, try again.\n\n")
                input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.

        fail() # Letting the player fail after three attempts. 

        
##############################################################################
          
          
    # Continuing the conditional statement, connected with bag_check, after the "What's missing Game"     
    elif bag_check == '2' or bag_check == 'no' in bag_check:
        print("""\n\nOk, never mind! Let's continue our journey. Next stop: New York 🗽!""")
        print(f"""\n\n\n{'▼△'*39}\n\n\n""") # Creating a nice desing to be printed at the end of the present stage.
        input("< Please, press any key to continue >\n") # Prompting player for input to continue the game.
        stop_newyork()
        
    else: # Creating an else statement to let the player input his/her choice again if something went wrong his/her input.
            print("\n\nOh no!😢 Something went wrong. Please, try again.\n\n")
            input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
            stop_hongkong() # Linking to stop_hongkong() stage to stop_hongkong() stage to try again.  

        
        

# Constructing my room_4, stop_newyork()

def stop_newyork():
    # Printing stop_newyork() stage introduction.
    print("""We almost made it! We are finally in New York, the big apple 🍎.\n\n""")
    input("< Please, press any key to continue >\n\n")
    
    # Prompting player for input, two choices are given, each of them leads to a different game path.  
    coffe = input(prompt = """Wait 🙌🏻 My friend, Eric, has just invited us for a coffee ☕️ break at his house. 
Would you like to go?
                                    1. Yes
                                    2. No
Please, input your number or name preference (e.g. Yes): """)
    
    # Converting path using .casefold() to remove case distiction present in the string.
    coffe = coffe.casefold()
                        
    # Creating a conditional statement, connected to the player coffe prompt
    if coffe == '1' or 'yes' in coffe:
        print("""\n\nGreat, let's go! I really need a coffe 😴""")
        input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
        print("""Eric has a very beautiful home, hasn't he? 🏡. But why has he left us alone❓ 
Time is money ⌛️. Let's go away!""")
        input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
        print("""Oh no!😢 We're stuck! He has locked us in 🗝.""")
        input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.

        
        
##############################################################################     
########################### The "Unlocking Game" #############################
##############################################################################
        

        # Generating a random code to unlock the door.
        code = random.randint(1, 10) + random.randint(1, 10) + random.randint(1, 10)

        # Defining the maximum number of attempts.
        attempts = 2

        # Creating a loop to allow player to make a code guessing attempt.
        while attempts > 0:
            code_attempt = input("""Find the right code to unlock the door 🔐  
(Hint 1: You have just three attempts.): """)

            if code_attempt == code:
                print('\n\n Amazing you unlock the door!🤩 We are finally free.\n')
                input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
                break
                win() # Linking to stop_newyork() stage to win() stage.

            elif code_attempt != code:
                attempts -= 1
                print('\n\n Oh no!😢 This code is not corret. The door is still locked 🔒\n')
                input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.

            else: # Creating an else statement to let the player input his/her choice again if something went wrong his/her input.
                chances += 1
                print("\n\nOh no!😢 Something went wrong. Please, try again.\n")
                input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
            
        fail() # Letting the player fail after three attempts.

##############################################################################

    
    # Continuation of the first nested conditional statement, eating_break
    elif coffe == '2' or 'no' in coffe:
        print("""\n\nRight! We cannot afford any distraction. Let's embark on the 
ship for London!🚢🇬🇧\n""")
        input("< Please, press any key to continue > \n") # Prompting player for input to continue the game.
        print("""(✏️ Author note: 
         🤫🤫 Hey player, you were right not to get that coffee. Eric was a criminal!     
         Who knows what challenges you would have faced!🤫🤫\n """)
        input("< Please, press any key to continue > \n") # Prompting player for input to continue the game.
        win() # Linking to stop_newyork() stage to the win() stage.
    
    else: # Creating an else statement to let the player input his/her choice again if something went wrong his/her input.
        print("\n\nOh no!😢 Something went wrong. Please, try again.\n")
        input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
        stop_newyork() # Linking to stop_newyork() stage to fail() stage to try again.
 
        

        
# Constructing fail()

def fail():
    print(f"""
{'❌' * 39}
                                                   
                              
                                 OH NO!😢
                               YOU FAILED!
                     
                            
{'❌' * 39}\n\n""")
    
    # Prompting player for input
    play_again = input(prompt = """⚠️ Would you like to play again? ⚠️
                                1. Yes
                                2. No
Please, input your preference (e.g. 1 or Yes): """)
    
    # Converting path using .casefold() to remove case distiction present in the string.
    play_again = play_again.casefold()
    
    # Defining a conditional statement 
    if play_again == '1' or 'yes' in play_again:
        print(f"""\n\n {'▼△'*16} LET'S DO ITTTT! 💪🏻 {'▼△'*16} \n\n""")
        input("< Please, press any key to continue >\n\n\n") # Prompting player for input to continue the game.
        introduction()
    
    
    elif play_again == '2' or 'no' in play_again:
        print("""\n""")
        # Creating special lists for a special goodbye.
        lst_1 = ['G', ' O', ' O', 'D', ' B', '  Y',' E', ' ', ' ']
        lst_2 = ['M', ' Y', ' ', ' ', ' F', 'R', ' I', '  E',' N', 'D', ' 💔', '🤧']

        # Creating a for loop for a special goodbye.
        for random_name in lst_1:
            print(random_name)

        for random_name in lst_2: 
            print(random_name)
        input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
        exit(0) # Linking to exit to exit the game.
        
        
    else: # Creating an else statement to let the player input his/her choice again if something went wrong his/her input.
        print("\n\nOh no!😢 Something went wrong. Please, try again.\n")
        input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
        fail() # Linking to fail() to let the player try again.

        
        
# Constructing win()

def win():
    print(f"""
{'・•◦🌎◦•・' * 9}
        
                                YOU MADE IT!!
                           💸 YOU KILL THE BET 💸
                            
        
{'・•◦🌎◦•・' * 9}""")
    
    # Prompting player for input
    play_again = input(prompt = """\n\n⚠️ Would you like to play again? ⚠️
                                1. Yes
                                2. No
Please, input your preference (e.g. 1 or Yes): """)
    
    # Converting path using .casefold() to remove case distiction present in the string.
    play_again = play_again.casefold()
                        
    # Defining a conditional statement 
    if play_again == '1' or 'yes' in play_again:
        print(f"""\n\n {'▼△'*16} LET'S DO ITTTT! 💪🏻 {'▼△'*16} \n\n""")
        input("< Please, press any key to continue >\n\n\n") # Prompting player for input to continue the game.
        introduction()
        
        
    elif play_again == '2' or 'no' in play_again:
        print("""\n""")
        # Creating special lists for a special goodbye.
        lst_1 = ['G', ' O', ' O', 'D', ' B', '  Y',' E', ' ', ' ']
        lst_2 = ['M', ' Y', ' ', ' ', ' F', 'R', ' I', '  E',' N', 'D', ' 💔', '🤧']

        # Creating a for loop for a special goodbye.
        for random_name in lst_1:
            print(random_name)

        for random_name in lst_2: 
            print(random_name)
        input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
        exit(0) # Linking to exit to exit the game.
        
        
    else: # Creating an else statement to let the player input his/her choice again if something went wrong his/her input.
        print("\n\nOh no!😢 Something went wrong. Please, try again.\n")
        input("< Please, press any key to continue >\n\n") # Prompting player for input to continue the game.
        fail() # Linking to fail() to let the player try again.
        
        
##############################################################################
introduction()
##############################################################################
